# %% [markdown]
# # Why use Pandas and Python when you already know Excel in and out?
#
# This is a very valid question and one that may have crossed your minds multiple times.
#
# ## 1. It enables you to work with all sorts of data, not just excel spreadsheets.
#
# While MS Excel is one of the most widely used data entering tools, in today's growing world, many more forms of data storing are becoming more and more prominent.
#
# Python and Pandas can actually handle more than just Excel sheets. As you have seen earlier, CSV files are easily imported. However, that is just one of many options available. In fact, Pandas supports your clipboard, SQL Databases, XML, JSON, SPSS, SAS and STATA data files as well (and many more), while regular Python is easily able to interface with No-SQL databases (like MongoDB) with ease and then export the output to Pandas. This means, more power to you!
#
# ![various_formats.png](various_formats_2.png)
# ![various_formats_2.png](various_formats.png)
#
# ## 2. Easier Automation and Reproducibility.
#
# When we need to run a lengthy analysis consisting of many steps, it requires a lot of remembering or grit work while automating some functionality in Excel using Macros. You need to perform the steps with actual button clicks, and in general, one needs to re-enter all the formulae in each Excel sheet where they would want to perform any analysis.
#
# In Python + Pandas, we can have such functionality implemented in a single script, and the run the script on many excel files, without having to copy-paste or re-enter any formulae. More time to you, and less effort. So its like we work very hard now to be extremely lazy later :)
#
# Python is also extremely reproducible because all the steps that you take to achieve the final analysis result are already written in code. You don't have to remember the specific order in which you performed those steps the first time you did it because you have already written the code to do it!
#
# This is not entirely possible in Excel, because the entire set of steps we take may sometimes be graphical, and get lost in the large multitude of procedures that we need to follow sometimes.
#
# ## 3. Enables easy working with huge datasets
#
# Excel and any other spreadsheet program for that matter have an upper limit on the amount of data it is able to handle with ease. It also stores the entire dataset in the memory and as a result, if you have a less powerful system, your computer starts to lag.
#
# Python (+ other modules) enables this to happen quite easily without the need for actually storing the data in the memory. When we say `pandas.read_csv`, it gives you the option to read it in fixed chunk-sizes which your computer can handle easily. As a result, your computer runs a lot faster and you are able to do the analysis on a comparably less powerful machine without needing to worry about anything.
#
# ## 4. Easier to find and fix errors
# When you’ve made an error in Excel, figuring out what’s gone wrong can be difficult, since you might have to scroll through thousands of cells of data to find the answer, or attempt to manually re-trace your steps.
#
# But when you make an error in Python, you’ll get an error message telling you exactly what went wrong. And of course, you can also have comments explaining each line of your code, making it easier to go back and re-check each step looking for mistakes. Typically, programmers also use a system for version control, so if you experience an error you haven’t before, you’ll be able to compare your current code with its previous iteration to get a sense of what’s gone wrong. (This is a useful feature available on GitHub as well.)
#
# ## 5. Free and Open Source
#
# Excel is not an open source software, nor is it free. You need to have some form of access to Excel, either by buying Microsoft Office 365, or some other form of it, or if you are lucky, your Workplace or University provides it to you for free. As a result, in case you ever lose access to Excel, you'll have to depend on the Open Source alternatives like LibreOffice Calc, or Google Spreadsheets, or some other thing. However, if you use Python, you have a rock-solid dependable piece of software running which no one can lay claim on, nor can it ever be made a paid product.
#
# Along with this, Python being open-source, if you ever have the need for any specific feature, you can always code it in yourself and contribute to the open-source community so that everyone benefits from your code. This is definitely not feasible with Excel.
#
# Also, Excel runs only on Windows and macOS. If you have ever used any form of Linux, you would know the pain of not having MS Office running on your computers. In such a case, Python is able to provide cross-compatible functionality in not only Windows, macOS and Linux, but also in iOS, Android, and various other platforms. Definitely worth it.
#
# ## 6. Machine Learning and Advanced Statistics Capabilites
#
# Excel has very good statistics capabilities, but Python has much much more. And Machine Learning libraries are non-existent in Excel, so if you want to do anything beyond basic regression, you would need to use VBScript code or something like that to write out the entire algorithm by yourself.
#
# In Python, such libraries are available for free, and you won't need to manually write code every time to implement the state-of-the-art algorithms, as they will be available to you from before, while at the same time, you have the liberty to write it if you want to. It's a feature you would never be able to match on Excel.
#
# You also get a lot better plotting software in general, leaps and bounds better than Excel plotting software, with very deep levels of control over details.

# %% [markdown]
# # Pandas for Excel Super Users
#
# Let's start from the beginning, one last time:

# %%
import pandas as pd

# %%
df1 = pd.read_excel("Financial Sample.xlsx")

df1
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %% [markdown]
# Now, the Excel sheet has 3 sheets in it, but we got the first one by default. This is because we didn't specify the `sheet_name` parameter, which enables us to choose which sheet.
#
# Now, let's try importing sheet "Zoo"

# %%
df2 = pd.read_excel("Financial Sample.xlsx", sheet_name='Zoo')

df2
# Out:
#       animal  uniq_id  water_need
# 0      zebra     1015          80
# 1      zebra     1014         100
# 2      zebra     1009         200
# 3      zebra     1010         220
# 4      zebra     1013         220
# 5      zebra     1012         230
# 6      zebra     1011         240
# 7      tiger     1007         290
# 8      tiger     1004         300
# 9      tiger     1008         310
# 10     tiger     1005         320
# 11     tiger     1006         330
# 12      lion     1019         390
# 13  kangaroo     1020         410
# 14  kangaroo     1022         410
# 15      lion     1016         420
# 16  kangaroo     1021         430
# 17  elephant     1001         500
# 18      lion     1018         500
# 19  elephant     1003         550
# 20  elephant     1002         600
# 21      lion     1017         600

# %% [markdown]
# That worked like a charm!
#
# We can use either the name of the sheet if we know it, or we can use indices (with the first sheet being index 0), as shown below:

# %%
df3 = pd.read_excel("Financial Sample.xlsx", sheet_name=2) # this is the third sheet, the empty one

df3
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Now, as I told you before, there is something called a Primary key, which contains the values that can uniquely identify a row entry. This can be also done in Pandas, using the `index_col` parameter while importing.
#
# Again, we can either use the column name or column number, with the first column being # 0.

# %%
df2 = pd.read_excel("Financial Sample.xlsx", sheet_name=1, index_col=1)

df2
# Out:
#            animal  water_need
# uniq_id
# 1015        zebra          80
# 1014        zebra         100
# 1009        zebra         200
# 1010        zebra         220
# 1013        zebra         220
# 1012        zebra         230
# 1011        zebra         240
# 1007        tiger         290
# 1004        tiger         300
# 1008        tiger         310
# 1005        tiger         320
# 1006        tiger         330
# 1019         lion         390
# 1020     kangaroo         410
# 1022     kangaroo         410
# 1016         lion         420
# 1021     kangaroo         430
# 1001     elephant         500
# 1018         lion         500
# 1003     elephant         550
# 1002     elephant         600
# 1017         lion         600

# %%
df2 = pd.read_excel("Financial Sample.xlsx", sheet_name=1, index_col='uniq_id')

df2
# Out:
#            animal  water_need
# uniq_id
# 1015        zebra          80
# 1014        zebra         100
# 1009        zebra         200
# 1010        zebra         220
# 1013        zebra         220
# 1012        zebra         230
# 1011        zebra         240
# 1007        tiger         290
# 1004        tiger         300
# 1008        tiger         310
# 1005        tiger         320
# 1006        tiger         330
# 1019         lion         390
# 1020     kangaroo         410
# 1022     kangaroo         410
# 1016         lion         420
# 1021     kangaroo         430
# 1001     elephant         500
# 1018         lion         500
# 1003     elephant         550
# 1002     elephant         600
# 1017         lion         600

# %% [markdown]
# As you see above, now that we have set the index column as the "uniq_id", the normal numbering that starts from 0 is no longer displayed.
#
# Now, we can also display only 5 columns or something like that using `head()` and `tail()`, but I've already taught you those, so I won't go over it again.

# %% [markdown]
# We will now learn to choose certain columns which we want (already done, I'm just showing it to you again):

# %%
df1[['Segment','Country','Sales']]
# Out:
#               Segment                   Country      Sales
# 0          Government                    Canada   32370.00
# 1          Government                   Germany   26420.00
# 2           Midmarket                    France   32670.00
# 3           Midmarket                   Germany   13320.00
# 4           Midmarket                    Mexico   37050.00
# ..                ...                       ...        ...
# 695    Small Business                    France  631125.00
# 696    Small Business                    Mexico  139230.00
# 697        Government                    Mexico    8139.60
# 698        Government                    Canada    4301.85
# 699  Channel Partners  United States of America   18421.20
#
# [700 rows x 3 columns]

# %% [markdown]
# Next, let's choose a single row:
#
# `loc` takes the name of the index, whereas `iloc` takes the row number. In case you haven't specified an index_column, then they both will be the same:

# %%
df1.loc[50]
# Out:
# Segment                        Channel Partners
# Country                United States of America
# Product                                Amarilla
# Discount Band                              None
# Units Sold                                 2141
# Manufacturing Price                         260
# Sale Price                                   12
# Gross Sales                               25692
# Discounts                                     0
# Sales                                     25692
# COGS                                       6423
# Profit                                    19269
# Date                        2014-08-01 00:00:00
# Month Number                                  8
# Month Name                               August
# Year                                       2014
# Name: 50, dtype: object

# %%
df1.iloc[50]
# Out:
# Segment                        Channel Partners
# Country                United States of America
# Product                                Amarilla
# Discount Band                              None
# Units Sold                                 2141
# Manufacturing Price                         260
# Sale Price                                   12
# Gross Sales                               25692
# Discounts                                     0
# Sales                                     25692
# COGS                                       6423
# Profit                                    19269
# Date                        2014-08-01 00:00:00
# Month Number                                  8
# Month Name                               August
# Year                                       2014
# Name: 50, dtype: object

# %% [markdown]
# Now, an example where they aren't the same:

# %%
df2.loc[1016]
# Out:
# animal        lion
# water_need     420
# Name: 1016, dtype: object

# %%
df2.iloc[13]
# Out:
# animal        kangaroo
# water_need         410
# Name: 1020, dtype: object

# %% [markdown]
# To access a single cell, we need to specify both the row and column, kind of like saying B10 in Excel:

# %%
df2.loc[1004]['animal']
# Out:
# 'tiger'

# %% [markdown]
# Next, if we want to display basic statistics of a column having **numerical data** (including the count, mean, standard deviation, min, 1st quartile, 2nd quartile, 3rd quartile, and max values), we use the `describe()` function

# %%
df2[['water_need']].describe()
# Out:
#        water_need
# count   22.000000
# mean   347.727273
# std    147.549243
# min     80.000000
# 25%    232.500000
# 50%    325.000000
# 75%    427.500000
# max    600.000000

# %% [markdown]
# If we want to display basic statistics of a column having **textual data** (including the count, number of uniques, most frequent values and their frequency), we use the `describe()` function on that

# %%
df2[['animal']].describe()
# Out:
#        animal
# count      22
# unique      5
# top     zebra
# freq        7

# %% [markdown]
# Now, I have downloaded a datasheet from [here](https://dq-blog-files.s3.amazonaws.com/movies.xls), which is available on the Google Drive (download the latest stuff if you haven't already).
#
# I'll be using that to show you how to merge 2 or more datasheets which have the same columns, so download it now if you want to try it out as I'm showing it.

# %%
movies1 = pd.read_excel("movies.xls", sheet_name = "1900s", index_col="Title")
movies2 = pd.read_excel("movies.xls", sheet_name = 1, index_col=0)
movies3 = pd.read_excel("movies.xls", sheet_name = "2010s", index_col=0)

# %%
movies1
# Out:
#                                                    Year  \
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916
# Over the Hill to the Poorhouse                     1920
# The Big Parade                                     1925
# Metropolis                                         1927
# Pandora's Box                                      1929
# ...                                                 ...
# Twin Falls Idaho                                   1999
# Universal Soldier: The Return                      1999
# Varsity Blues                                      1999
# Wild Wild West                                     1999
# Wing Commander                                     1999
#
#                                                                          Genres  \
# Title
# Intolerance: Love's Struggle Throughout the Ages              Drama|History|War
# Over the Hill to the Poorhouse                                      Crime|Drama
# ...

# %%
movies2
# Out:
#                                    Year  \
# Title
# 102 Dalmatians                     2000
# 28 Days                            2000
# 3 Strikes                          2000
# Aberdeen                           2000
# All the Pretty Horses              2000
# ...                                 ...
# X-Men Origins: Wolverine           2009
# Year One                           2009
# Youth in Revolt                    2009
# ZMD: Zombies of Mass Destruction   2009
# Zombieland                         2009
#
#                                                                      Genres  \
# Title
# 102 Dalmatians                                      Adventure|Comedy|Family
# 28 Days                                                        Comedy|Drama
# 3 Strikes                                                            Comedy
# Aberdeen                                                              Drama
# All the Pretty Horses                                 Drama|Romance|Western
# ...

# %%
movies3
# Out:
#                                         Year  \
# Title
# 127 Hours                             2010.0
# 3 Backyards                           2010.0
# 3                                     2010.0
# 8: The Mormon Proposition             2010.0
# A Turtle's Tale: Sammy's Adventures   2010.0
# ...                                      ...
# War & Peace                              NaN
# Wings                                    NaN
# Wolf Creek                               NaN
# Wuthering Heights                        NaN
# Yu-Gi-Oh! Duel Monsters                  NaN
#
#                                                                          Genres  \
# Title
# 127 Hours                                    Adventure|Biography|Drama|Thriller
# 3 Backyards                                                               Drama
# 3                                                          Comedy|Drama|Romance
# 8: The Mormon Proposition                                           Documentary
# ...

# %%
movies = pd.concat(movies1, movies2, movies3)

movies
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-7723bf244223> in <module>
# ----> 1 movies = pd.concat(movies1, movies2, movies3)
#       2
#       3 movies
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# --> 281         sort=sort,
#     282     )
#     283
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     307                 "first argument must be an iterable of pandas "
#     308                 "objects, you passed an object of type "
# --> 309                 '"{name}"'.format(name=type(objs).__name__)
#     310             )
# ...

# %% [markdown]
# As you see above, you need to put it into a list, or else Python goes crazy :\

# %%
movies = pd.concat([movies1, movies2, movies3])

movies
# Out:
#                                                      Year  \
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916.0
# Over the Hill to the Poorhouse                     1920.0
# The Big Parade                                     1925.0
# Metropolis                                         1927.0
# Pandora's Box                                      1929.0
# ...                                                   ...
# War & Peace                                           NaN
# Wings                                                 NaN
# Wolf Creek                                            NaN
# Wuthering Heights                                     NaN
# Yu-Gi-Oh! Duel Monsters                               NaN
#
#                                                                                       Genres  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                           Drama|History|War
# ...

# %%
movies.shape
# Out:
# (5042, 24)

# %%
df1
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df2
# Out:
#            animal  water_need
# uniq_id
# 1015        zebra          80
# 1014        zebra         100
# 1009        zebra         200
# 1010        zebra         220
# 1013        zebra         220
# 1012        zebra         230
# 1011        zebra         240
# 1007        tiger         290
# 1004        tiger         300
# 1008        tiger         310
# 1005        tiger         320
# 1006        tiger         330
# 1019         lion         390
# 1020     kangaroo         410
# 1022     kangaroo         410
# 1016         lion         420
# 1021     kangaroo         430
# 1001     elephant         500
# 1018         lion         500
# 1003     elephant         550
# 1002     elephant         600
# 1017         lion         600

# %%
dffull = pd.concat([df1, df2])

dffull
# Out:
#          Segment  Country    Product Discount Band  Units Sold  \
# 0     Government   Canada  Carretera          None      1618.5
# 1     Government  Germany  Carretera          None      1321.0
# 2      Midmarket   France  Carretera          None      2178.0
# 3      Midmarket  Germany  Carretera          None       888.0
# 4      Midmarket   Mexico  Carretera          None      2470.0
# ...          ...      ...        ...           ...         ...
# 1001         NaN      NaN        NaN           NaN         NaN
# 1018         NaN      NaN        NaN           NaN         NaN
# 1003         NaN      NaN        NaN           NaN         NaN
# 1002         NaN      NaN        NaN           NaN         NaN
# 1017         NaN      NaN        NaN           NaN         NaN
#
#       Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales  \
# 0                     3.0        20.0      32370.0        0.0  32370.0
# ...

# %% [markdown]
# # Sorting

# %% [markdown]
# Now, let us sort these movies in decreasing order of gross earnings.

# %%
sorted_by_gross = movies.sort_values(['Gross Earnings'], ascending=False)
sorted_by_gross
# Out:
#                                         Year  \
# Title
# Avatar                                2009.0
# Titanic                               1997.0
# Jurassic World                        2015.0
# The Avengers                          2012.0
# The Avengers                          2012.0
# ...                                      ...
# War & Peace                              NaN
# Wings                                    NaN
# Wolf Creek                               NaN
# Wuthering Heights                        NaN
# Yu-Gi-Oh! Duel Monsters                  NaN
#
#                                                                          Genres  \
# Title
# Avatar                                          Action|Adventure|Fantasy|Sci-Fi
# Titanic                                                           Drama|Romance
# Jurassic World                                 Action|Adventure|Sci-Fi|Thriller
# The Avengers                                            Action|Adventure|Sci-Fi
# ...

# %%
sorted_by_name = movies.sort_values(['Title'], ascending=True)


pd.set_option('display.max_rows', 100)
sorted_by_name.head(100)
# Out:
#                                                       Year  \
# Title
# #Horror                                             2015.0
# 10 Cloverfield Lane                                 2016.0
# 10 Days in a Madhouse                               2015.0
# 10 Things I Hate About You                          1999.0
# 10,000 B.C.                                            NaN
# 102 Dalmatians                                      2000.0
# 10th & Wolf                                         2006.0
# 11:14                                               2003.0
# 12 Angry Men                                        1957.0
# 12 Monkeys                                             NaN
# 12 Rounds                                           2009.0
# 12 Years a Slave                                    2013.0
# 127 Hours                                           2010.0
# 13 Going on 30                                      2004.0
# 13 Hours                                            2016.0
# ...

# %% [markdown]
# As you can see, Avatar is the highest grossing movie as per this list... Let's not get distracted though :)

# %% [markdown]
# # Filtering
# Next, we will learn about the Filtering methods. (it was done, but only partially)
#
# We will learn to filter a column according to our needs:

# %%
d = movies['Genres'] == 'Action|Adventure|Fantasy|Sci-Fi'
#d
movies[d]
# Out:
#                                                    Year  \
# Title
# Star Wars: Episode IV - A New Hope               1977.0
# Star Wars: Episode V - The Empire Strikes Back   1980.0
# Star Wars: Episode VI - Return of the Jedi       1983.0
# Beastmaster 2: Through the Portal of Time        1991.0
# Star Wars: Episode I - The Phantom Menace        1999.0
# Highlander: Endgame                              2000.0
# Star Wars: Episode II - Attack of the Clones     2002.0
# The League of Extraordinary Gentlemen            2003.0
# Star Wars: Episode III - Revenge of the Sith     2005.0
# Avatar                                           2009.0
# Man of Steel                                     2013.0
# Destiny                                          2014.0
# The Amazing Spider-Man 2                         2014.0
#
#                                                                           Genres  \
# Title
# ...

# %%
# Multiple matching:

c = movies['Genres'].isin(['Action|Adventure|Fantasy|Sci-Fi','Fantasy|Mystery|Thriller'])
#c
movies[c]
# Out:
#                                                    Year  \
# Title
# Star Wars: Episode IV - A New Hope               1977.0
# Star Wars: Episode V - The Empire Strikes Back   1980.0
# Star Wars: Episode VI - Return of the Jedi       1983.0
# Beastmaster 2: Through the Portal of Time        1991.0
# Star Wars: Episode I - The Phantom Menace        1999.0
# Highlander: Endgame                              2000.0
# Star Wars: Episode II - Attack of the Clones     2002.0
# The League of Extraordinary Gentlemen            2003.0
# Star Wars: Episode III - Revenge of the Sith     2005.0
# Avatar                                           2009.0
# Triangle                                         2009.0
# Man of Steel                                     2013.0
# Destiny                                          2014.0
# The Amazing Spider-Man 2                         2014.0
#
#                                                                           Genres  \
# Title
# ...

# %%
# Filter all the movies that grossed more than 100,000,000

movies[movies['Gross Earnings'] >= 100000000]
# Out:
#                                     Year                            Genres  \
# Title
# Snow White and the Seven Dwarfs   1937.0  Animation|Family|Fantasy|Musical
# Gone with the Wind                1939.0         Drama|History|Romance|War
# Bambi                             1942.0            Animation|Drama|Family
# Mary Poppins                      1964.0     Comedy|Family|Fantasy|Musical
# Doctor Zhivago                    1965.0                 Drama|Romance|War
# ...                                  ...                               ...
# The Jungle Book                   2016.0    Adventure|Drama|Family|Fantasy
# The Legend of Tarzan              2016.0    Action|Adventure|Drama|Romance
# The Legend of Tarzan              2016.0    Action|Adventure|Drama|Romance
# The Secret Life of Pets           2016.0           Animation|Comedy|Family
# X-Men: Apocalypse                 2016.0           Action|Adventure|Sci-Fi
#
# ...

# %%
# Combining multiple conditions:

movies[(movies['Gross Earnings'] >= 100000000) | (movies['Genres']=='Action|Adventure|Sci-Fi')].head(100)



# be sure to put them within brackets to prevent any weird errors from popping up
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5fea46ce54ef> in <module>
#       1 # Combining multiple conditions:
#       2
# ----> 3 movies[(movies['Gross Earnings'] >= 100000000) | (movies['Genres']=='Action|Adventure|Sci-Fi')].head(100)
#       4
#       5
#
# NameError: name 'movies' is not defined

# %% [markdown]
# # Pivot Tables
#
# If you are an Excel superuser, you must have used Pivot Tables on many occasions. Let's see how to use them in pandas:

# %%
df1
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
#sum
import numpy as np
#np.mean
pd.pivot_table(df1,values='Units Sold',index='Country',aggfunc = np.std)
# Out:
#                           Units Sold
# Country
# Canada                    873.577036
# France                    839.390360
# Germany                   827.869860
# Mexico                    777.702180
# United States of America  965.140317

# %%
pd.pivot_table(df1,values=['Units Sold'],index=['Country','Product'],aggfunc=[sum,np.mean,len])
# Out:
#                                           sum         mean        len
#                                    Units Sold   Units Sold Units Sold
# Country                  Product
# Canada                   Amarilla     29232.0  1624.000000       18.0
#                          Carretera    34804.0  1740.200000       20.0
#                          Montana      31488.5  1749.361111       18.0
#                          Paseo        78191.5  1861.702381       42.0
#                          VTT          41248.5  1874.931818       22.0
#                          Velo         32464.0  1623.200000       20.0
# France                   Amarilla     31603.0  1755.722222       18.0
#                          Carretera    34056.0  1892.000000       18.0
#                          Montana      31282.0  1564.100000       20.0
#                          Paseo        71606.0  1790.150000       40.0
#                          VTT          35774.5  1626.113636       22.0
# ...

# %% [markdown]
# # VLOOKUPs
#
# VLOOKUPs are possible in Excel, but I don't know it well enough to teach it. Here's a link if you want to learn it better:
#
# [Intro to Pandas for Excel Super Users](https://towardsdatascience.com/intro-to-pandas-for-excel-super-users-dac1b38f12b0)

# %% [markdown]
# # Graphing

# %% [markdown]
# Now, we will learn to do the very basics of graphing... Let's import matplotlib.pyplot for this purpose:

# %%
import matplotlib.pyplot as plt

# %%
x = np.sin(np.arange(0,7,0.01))
plt.plot(x)
plt.xlabel("x")
plt.ylabel("sin(x)")
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
y = df1["Units Sold"].values
type(y)

#plt.plot(y,'bo')
x = np.arange(10)**2
y = np.arange(10)**3
plt.plot(x,y,'bo')

# %%
9**3
# Out:
# 729

# %%
choice = np.random.randint(1,4,[100,1])
#print(choice)

# %%
dice1 = np.random.randint(1,7,[100,1])
dice2 = np.random.randint(1,7,[100,1])
#print(np.hstack([dice1,dice2]))

# %%
sumdice = dice1+dice2
#print(sumdice)

# %%
moneyrcvd = np.repeat(10,100).reshape([100,1])
#print(moneyrcvd)

# %%
payout=[]
for i in range(100):
    if sumdice[i] == 7 and choice[i] == 2:
        payout.append(30)
    elif (sumdice[i] < 7 and choice[i] == 1) or (sumdice[i] > 7 and choice[i] == 3):
        payout.append(20)
    else:
        payout.append(0)
#print(payout)
retain = moneyrcvd.reshape(-1)-np.array(payout)
cumul = []
summation = 0
#print(retain)
for i in retain:
    summation+=int(i)
    #print(summation)
    cumul.append(summation)

    
#print(cumul)
plt.plot(cumul,'bo:')
plt.title("Cumulative Money")
# Out:
# Text(0.5, 1.0, 'Cumulative Money')

# %%
#table = pd.concat(choice, dice1, dice2, sumdice, moneyrcvd, payout, retain, cumul)

# %%
table = pd.DataFrame(
    {'Choice': choice.reshape(-1),
     'Dice 1': dice1.reshape(-1),
     'Dice 2': dice2.reshape(-1),
     'Sum of Dice': sumdice.reshape(-1),
     'Money Received': moneyrcvd.reshape(-1),
     "Pay out": payout,
     "Retained Amount": retain.reshape(-1),
     "Cumulative amount": cumul
    })
table
# Out:
#     Choice  Dice 1  Dice 2  Sum of Dice  Money Received  Pay out  \
# 0        1       5       1            6              10       20
# 1        1       1       4            5              10       20
# 2        1       3       6            9              10        0
# 3        2       5       3            8              10        0
# 4        2       3       1            4              10        0
# 5        3       6       6           12              10       20
# 6        2       2       1            3              10        0
# 7        2       5       2            7              10       30
# 8        1       3       2            5              10       20
# 9        3       3       5            8              10       20
# 10       3       6       1            7              10        0
# 11       1       3       1            4              10       20
# 12       1       3       4            7              10        0
# ...

# %% [markdown]
# # Try changing the values of the max players and the amount paid and find the one which gives a very high profit.
