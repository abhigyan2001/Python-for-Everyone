# %% [markdown]
# # 1. Correct the following code according to the directions given:

# %% [markdown]
# ## a) This code should take an input and not just simply print enter your name... Please correct this code and make it do the right thing.

# %%
nm= input("Please enter your name: ")
print("Hello ",nm)
# Out:
# Please enter your name: Shviti
# Hello  Shviti

# %% [markdown]
# ## b) The next code should not give any errors. Do something to stop that from happening:
#
# (You can correct the code without adding anything extra, or you can add something that will take care of it)

# %%
print("¡Hola mi amigo! ¿Cuál es tu nombre?")
print("¡Hola! Mi nombre es Abhigyan")
print("See? It's that easy!")
# Out:
# ¡Hola mi amigo! ¿Cuál es tu nombre?
# ¡Hola! Mi nombre es Abhigyan
# See? It's that easy!

# %% [markdown]
# ## c) Correct the syntax of all the statements below

# %%
print ("I'm a Python 2 code to find the area of a rectangle")

y = 10
x = 5

area = lambda x,y: x*y

print(area(x,y))

s = "Helloworld!"

print(s[1],s[5],s[2])

# the code below should print the elements in string 's'
def FastForward(s,n):
    print(s[::n])
    
FastForward("¡Hola!",1)
# Out:
# I'm a Python 2 code to find the area of a rectangle
# 50
# e w l
# ¡Hola!

# %% [markdown]
# <details>
#   <summary>Hint</summary>
#
#   Maybe try changing the commas and colons, and remove the plus in x+=5, also, try to remove the double quotes in the print under the function
# </details>

# %% [markdown]
# # 2. Predict the output of the following codes before running them:
#
# (I have no way of checking if you were honest with yourself in these ones, so I'm trusting all of you on this one... Don't make me regret it ;) )

# %% [markdown]
# a)

# %%
s = "¡Hola Mundo!"
print(s[::4])
# Out:
# ¡an

# %% [markdown]
# b)

# %%
q = "Estoy disfrutando Python!"

for i in q:
    print(i)
# Out:
# E
# s
# t
# o
# y
#
# d
# i
# s
# f
# r
# u
# t
# a
# n
# d
# o
#
# P
# y
# t
# h
# o
# n
# !

# %% [markdown]
# c)

# %%
sentence = ["Hi", "we", "have", "completed", 5, "days", "of", "these", "Python", "classes"]
print(type(sentence))

for word in sentence:
    print(word)
    print(type(word))

for word in sentence:
    if isinstance(word, str): # the `isinstance` function just checks if the variable (here `word`)
                              # is of the specified class/type (here `str`)
        for letter in word:
            print(letter)
# Out:
# <class 'list'>
# Hi
# <class 'str'>
# we
# <class 'str'>
# have
# <class 'str'>
# completed
# <class 'str'>
# 5
# <class 'int'>
# days
# <class 'str'>
# of
# <class 'str'>
# these
# <class 'str'>
# Python
# <class 'str'>
# classes
# <class 'str'>
# H
# i
# w
# e
# h
# a
# v
# e
# c
# o
# m
# p
# l
# e
# t
# e
# d
# d
# a
# y
# s
# o
# f
# t
# h
# e
# s
# e
# P
# y
# t
# h
# o
# n
# c
# l
# a
# s
# s
# e
# s

# %% [markdown]
# d)

# %%
walkerList = {"All falls Down":2017, "Faded":2015, "Alone Pt 2":2020, "Sing me to Sleep":2016, "Alone":2016, "Tired":2017}
print(type(walkerList))

for i in walkerList: #turns out dicts are iterable too! I just got to know! 
    #I don't dicts much because normally lists serve most needs in everyday code, and I feel you will do the same eventually.
    #Generally, dicts and tuples are some of the most underused data types, but they're definitely useful in their own ways...
    print(i)
    print(type(i))
    print(walkerList[i])
    print(type(walkerList[i]))

# %% [markdown]
# # 3. Code Questions

# %% [markdown]
# ## a) Create a simple calculator with your new knowledge of loops
#
# Ask the user for which operation they want to use (all the options should be displayed clearly)
#
# Example menu:
# ```
# Which operation would you like to perform next?
# 1. Add (+)
# 2. Subtract (-)
# 3. Multiply (*)
# 4. Divide (normally) (/)
# 5. Integer Division (//)
# 6. Exponentiation (**)
# ```
# Now, depending on which number the user presses (1 for Add, 3 for Multiply, and so on...), you should perform the given operation and display the result on the screen, and then ask the user if he wants to perform another calculation. If yes, then display the menu again, else, exit the loop.
#
# Take care of invalid inputs too...
#
# ### Example interaction (very important, read the whole thing):
#
# ```
# Which operation would you like to perform next?
# 1. Add (+)
# 2. Subtract (-)
# 3. Multiply (*)
# 4. Divide (normally) (/)
# 5. Integer Division (//)
# 6. Exponentiation (**)
#
# Enter your choice: 1
# Enter first value: 12
# Enter second value: 23
# x+y = 35.0
# Do you want to perform another calculation? (Enter y/n): yeah
# Please enter a valid option...
# Do you want to perform another calculation? (Enter y/n): no
# Please enter a valid option...
# Do you want to perform another calculation? (Enter y/n): y
# Starting next round...
# Which operation would you like to perform next?
# 1. Add (+)
# 2. Subtract (-)
# 3. Multiply (*)
# 4. Divide (normally) (/)
# 5. Integer Division (//)
# 6. Exponentiation (**)
#
# Enter your choice: 2
# Enter first value: 45
# Enter second value: 23
# x-y = 22.0
# Do you want to perform another calculation? (Enter y/n): y
# Starting next round...
# Which operation would you like to perform next?
# 1. Add (+)
# 2. Subtract (-)
# 3. Multiply (*)
# 4. Divide (normally) (/)
# 5. Integer Division (//)
# 6. Exponentiation (**)
#
# Enter your choice: 3
# Enter first value: 34
# Enter second value: 2
# x*y = 68.0
# Do you want to perform another calculation? (Enter y/n): y
# Starting next round...
# Which operation would you like to perform next?
# 1. Add (+)
# 2. Subtract (-)
# 3. Multiply (*)
# 4. Divide (normally) (/)
# 5. Integer Division (//)
# 6. Exponentiation (**)
#
# Enter your choice: 4
# Enter first value: 12
# Enter second value: 6
# x/y = 2.0
# Do you want to perform another calculation? (Enter y/n): y
# Starting next round...
# Which operation would you like to perform next?
# 1. Add (+)
# 2. Subtract (-)
# 3. Multiply (*)
# 4. Divide (normally) (/)
# 5. Integer Division (//)
# 6. Exponentiation (**)
#
# Enter your choice: 5
# Enter first value: 12
# Enter second value: 6
# x//y = 2.0
# Do you want to perform another calculation? (Enter y/n): y
# Starting next round...
# Which operation would you like to perform next?
# 1. Add (+)
# 2. Subtract (-)
# 3. Multiply (*)
# 4. Divide (normally) (/)
# 5. Integer Division (//)
# 6. Exponentiation (**)
#
# Enter your choice: 6
# Enter first value: 2.718
# Enter second value: 4
# x**y = 54.575510850575995
# Do you want to perform another calculation? (Enter y/n): y
# Starting next round...
# Which operation would you like to perform next?
# 1. Add (+)
# 2. Subtract (-)
# 3. Multiply (*)
# 4. Divide (normally) (/)
# 5. Integer Division (//)
# 6. Exponentiation (**)
#
# Enter your choice: 100
# Please enter a valid number (1, 2, 3, 4, 5 or 6)
# Which operation would you like to perform next?
# 1. Add (+)
# 2. Subtract (-)
# 3. Multiply (*)
# 4. Divide (normally) (/)
# 5. Integer Division (//)
# 6. Exponentiation (**)
#
# Enter your choice: 1
# Enter first value: 9000
# Enter second value: 90
# x+y = 9090.0
# Do you want to perform another calculation? (Enter y/n): n
# Exiting the loop
# ```

# %%
# Enter your code here

def getValidOption():    
    print("""Which operation would you like to perform next?
    1. Add (+)
    2. Subtract (-)
    3. Multiply (*)
    4. Divide (normally) (/)
    5. Integer Division (//)
    6. Exponentiation (**)""" )

    option=input("Enter your choice:")
    
    inp=-1
    try:
        inp=int(option)        
    except ValueError:
        print("Please enter a valid number (1, 2, 3, 4, 5 or 6)")
        getValidOption()     
    if(inp < 1 or inp > 6):
        print("Please enter a valid number (1, 2, 3, 4, 5 or 6)")
        getValidOption()
    #valid input, return it    
    return inp

def operations(option,x,y):        
    if(option == 1):
        print("x+y=",x+y)
    if(option == 2):
        print("x-y=",x-y)
    if(option == 3):
        print("x*y=",x*y)
    if(option == 4):
        print("x/y=",x/y)
    if(option == 5):
        print("x//y=",x//y)
    if(option == 6):        
        print("x**y=",x**y)
    return
    

def calculator():
    option=getValidOption()    
    x=input("Enter first value:")
    y=input("Enter second value:")
    try:
        x1=int(x)
        y1=int(y)        
    except ValueError:
        print("Please enter valid number only")
        
    operations(option,x1,y1)
    ans="B" #any random value
    while (ans != "n"):
        ans=input("Do you want to perform another calculation? (Enter y/n):")    
        if(ans == "y"):
            print("Starting next round...")
            calculator()
        elif(ans != "n"):
            print("Please enter a valid option...")
        else:
            return
    #while loop ends    
    return

#call function
calculator()
# Out:
# Which operation would you like to perform next?
#     1. Add (+)
#     2. Subtract (-)
#     3. Multiply (*)
#     4. Divide (normally) (/)
#     5. Integer Division (//)
#     6. Exponentiation (**)
# Enter your choice:1
# Enter first value:2
# Enter second value:3
# x+y= 5
# Do you want to perform another calculation? (Enter y/n):No
# Please enter a valid option...
# Do you want to perform another calculation? (Enter y/n):y
# Starting next round...
# Which operation would you like to perform next?
#     1. Add (+)
#     2. Subtract (-)
#     3. Multiply (*)
#     4. Divide (normally) (/)
#     5. Integer Division (//)
#     6. Exponentiation (**)
# Enter your choice:2
# Enter first value:2
# Enter second value:3
# x-y= -1
# Do you want to perform another calculation? (Enter y/n):n
# Do you want to perform another calculation? (Enter y/n):n

# %% [markdown]
# ## b) Create a better billing system for PlusPoint Hypermarket
#
# Ask the user for entering an item repeatedly
#
# Come up with your own pricing mechanisms :)
#
# You could even ask the user to enter the price they want, but then they could just enter 0 for everything... Not ideal for a real supermarket huh?
#
# I just want to see how you would do the pricing part, there's no penalty for allowing the user to enter their own prices, but if you have a better idea, then please do show me!
#
# ### Example interaction (very important, read the whole thing):
#
# <pre>
# Enter the number of items you want to buy: 4
# Enter an Item name: Lays Indian Masala Flavour
# Enter the Cost: 20
# Enter the Quantity you wish to purchase: 2
# Enter an Item name: Pepsi 600ml
# Enter the Cost: 80
# Enter the Quantity you wish to purchase: 2
# Enter an Item name: Tissue Papers
# Enter the Cost: 0
# Enter the Quantity you wish to purchase: 50
# Please enter a more realistic price and quantity ;)
# Enter an Item name: Tissue Papers
# Enter the Cost: 2000000000
# Enter the Quantity you wish to purchase: 50
# Please enter a more realistic price ;)
# Enter an Item name: Tissue Papers
# Enter the Cost: 50
# Enter the Quantity you wish to purchase: 50
# Enter an Item name: Maida 1kg
# Enter the Cost: 40
# Enter the Quantity you wish to purchase: 3
#
# 				Plus Point Hypermarket
#
# | Name                  | Cost      | Quantity  | Total          |
#  ________________________________________________________________
# | Lays Indian Ma        | 20.0      | 2         | 40.0           |
# | Pepsi 600ml           | 80.0      | 2         | 160.0          |
# | Tissue Papers         | 50.0      | 50        | 2500.0         |
# | Maida 1kg             | 40.0      | 3         | 120.0          |
# </pre>

# %%
# Enter your code here

class PurchaseItem:
    def __init__(self,name,cost,quantity):
        self.name=name
        self.cost=cost
        self.quantity=quantity
        
    def validate(self):
        isValid=True
        if((self.cost<=0 or self.cost>2000) and (self.quantity<=0 or self.quantity>50)):
            print("Please enter a more realistic price and quantity ;)")
            isValid=False
        elif((self.cost<=0 or self.cost>2000)):
            print("Please enter a more realistic price ;)")
            isValid=False
        elif((self.quantity<=0 or self.quantity>50)):
            print("Please enter a more realistic quantity ;)")
            isValid=False
        #validations complete,return
        return isValid
 
                
def shopping():
    itemsNum=input("Enter the number of items you want to buy:")
    noOfItems=0
    try:
        noOfItems=int(itemsNum)               
    except ValueError:
        print("Please enter valid number only")
       
    itemList=[]
    i=0
    while(i < noOfItems):
        name=input("Enter an Item name:")
        cost=input("Enter the Cost:")
        quantity=input("Enter the Quantity you wish to purchase:")
        #needs error handling for type check before conversion to float
        p=PurchaseItem(name,float(cost),float(quantity)) 
        if(p.validate()):            
            itemList.append(p)
            i += 1        
    #item entry over.
    
    #now print the bill
    print("\t\t\tPlus Point Hypermarket")
    print("| Name                  | Cost      | Quantity  | Total          |")
    print("--------------------------------------------------------------------")
    for j in itemList:
        #print(j)
        print("|",j.name,"\t\t|",j.cost,"\t\t|",j.quantity,"\t\t|",j.cost*j.quantity,"|")
    
    print("Thanks for shopping with us!")
    
shopping()
# Out:
# Enter the number of items you want to buy:2
# Enter an Item name:Lays Indian Masala
# Enter the Cost:12
# Enter the Quantity you wish to purchase:80
# Please enter a more realistic quantity ;)
# Enter an Item name:5
# Enter the Cost:123
# Enter the Quantity you wish to purchase:2
# Enter an Item name:Lool
# Enter the Cost:100000
# Enter the Quantity you wish to purchase:0
# Please enter a more realistic price and quantity ;)
# Enter an Item name:Lool
# Enter the Cost:100
# Enter the Quantity you wish to purchase:0
# Please enter a more realistic quantity ;)
# Enter an Item name:Lool
# Enter the Cost:100
# Enter the Quantity you wish to purchase:0
# Please enter a more realistic quantity ;)
# Enter an Item name:Lool
# Enter the Cost:100
# Enter the Quantity you wish to purchase:2
# 			Plus Point Hypermarket
# | Name                  | Cost      | Quantity  | Total          |
# --------------------------------------------------------------------
# | 5 		| 123.0 		| 2.0 		| 246.0 |
# | Lool 		| 100.0 		| 2.0 		| 200.0 |
# Thanks for shopping with us!
