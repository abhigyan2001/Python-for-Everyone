# %% [markdown]
# # Let's do MatPlotLib properly this time!

# %%
import matplotlib.pyplot as plt
import numpy as np # importing numpy as well

# %% [markdown]
# By running this special iPython command, we will be displaying plots inline:

# %%
#%matplotlib notebook

# this produces an interactive plot

# other option is %matplotlib inline => shows the plots as a single plot which is non-interactable

# %matplotlib inline

# %% [markdown]
# ## Plotting

# %% [markdown]
# ### Line Graphs

# %%
# Compute the x and y coordinates for points on a sine curve
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

# Plot the points using matplotlib
plt.plot(x, y) # this function is used to create a plot with a line passing through the x and y points
plt.show()

# %% [markdown]
# **What happens if I plot on a figure twice?**
#
# Everytime we use the plot function it tries to plot the given data on the already existing figure.
#
# Hence if do it twice both of them get plotted on the same plot.
#
# The `label` parameter of the plot function is used to label a line plot. The labels can be viewed by writing ```plt.legend()```

# %%
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

# Plot once
plt.plot(x, y, label="sine") 

y = np.cos(x)
#plot twice
plt.plot(x, y, label="cosine") 
# viewing the legend
plt.legend()
plt.show()

# %% [markdown]
# **What if we wanted two seperate plots?**
#
# Use the ```plt.figure()``` command to create a new figure and the plot command will follow this will plot the data on the last opened figure

# %%
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

# Plot once
plt.figure()
plt.plot(x, y, label="sine") 

y = np.cos(x)
#plot twice
plt.figure()
plt.plot(x, y, label="cosine")
plt.show()

# %% [markdown]
# ## Labelling the axis, figure, changing the xticks
#
# ```plt.xlabel(), plt.ylabel()``` - to change x and y labels
#
# ```plt.xticks(), plt.yticks()``` - to change x and y ticks/markers
#
# ```plt.title``` - to change title
#
# Also the ```plt.show()``` has to be called everytime you want to plot the figures. (required when you want to plot in .py files.)

# %%
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

plt.plot(x, y)
# setting the title
plt.title("Sine curve")
# setting the x and y labels
plt.xlabel("X")
plt.ylabel("Y")

# changing the x ticks

# np.arange(a,b,c) a = start, b = end (excluded), c = step

plt.xticks(np.arange(0,10,0.5))
plt.yticks(np.arange(-1.5,1.5,0.1))

# use to view all the figures plotted so far. Has to be called when working with py files.
plt.show()

# %% [markdown]
# ## Scatter plots

# %%
# list data for x and y
#x = [1,2,3,4,5]
#y = [3,4,5,6,7]

x = np.arange(5,0,-1)
y = np.arange(3,8)

# scatter plots
#plt.scatter(x,y,marker="^")
plt.plot(x,y,"bo")

# %% [markdown]
# ## Format Strings:
#
# `fmt = "[marker][line][color]"`
#
# RGB = (0,0,255) == blue
#
# 0123456789abcdef
#
# ff0000 = red (255,0,0)

# %% [markdown]
# ## Adding color
#
# An image is a collection of pixels. Each pixel is represented by 3 values = (R,G,B) values. Each of the correspond to intensity of Red, Blue and Green.
#
# In matplotlib to assign a color the parameter c is used which is the normalised values of a pixel color meaning dividing the (R,G,B) values by 255.0.
#
# Hence the color Red = (255,0,0) will be represented by (1.0,0,0).
#
# Here the paramter c is a list containing tuples representing the color of each data point

# %%
# assigning colors

plt.scatter(x,y, c = [(1,1,1)]*len(x))


plt.plot(x,y,color=(1,1,0),marker="o",linestyle="--")

# %% [markdown]
# ## Changing marker symbols:
#
# <sub>All valid marker symbols are given here: https://matplotlib.org/3.2.1/api/markers_api.html</sub>

# %%
plt.scatter(x,y, marker="*")

# %% [markdown]
# # Bar plots

# %%
# x-axis values 
x = ["A+ve", "B+ve", "AB+ve", "O+ve", "Others"]
# Y-axis values 
y = [4, 2, 0, 6, 9]
  
# Function to plot the bar 
plt.bar(x,y) 
  
# function to show the plot 
plt.show()

# %% [markdown]
# ## MatPlotLib object Hierarchy

# %% [markdown]
# A huge concept of matplotlib is the matplotlib object hierarchy.
# In the previous code cells, we have called plt.plot(x,y). This one-liner hides the fact that a plot is really a hierarchy of nested Python objects. A “hierarchy” here means that there is a tree-like structure of matplotlib objects underlying each plot.
#
# A Figure object is the outermost container for a matplotlib graphic, which can contain multiple Axes objects. One source of confusion is the name: an Axes actually translates into what we think of as an individual plot or graph (rather than the plural of “axis,” as we might expect).
#
# You can think of the Figure object as a box-like container holding one or more Axes (actual plots). Below the Axes in the hierarchy are smaller objects such as tick marks, individual lines, legends, and text boxes. Almost every “element” of a chart is its own manipulable Python object, all the way down to the ticks (reference points on a scale) and labels:

# %%
fig = plt.figure()
print(fig) # prints an empty container with 0 axes.
# Out:
# Figure(432x288)

# %% [markdown]
# # Understanding subplots
#
# plt.subplots(n,n) divides the matplotlib figure into nxn layout each having its own axis (plots).
#
# To plot in a specific axis, we choose the particular index and use the plot function

# %%
# diving matplotlib figure into 2x2 
fig, ax = plt.subplots(2,2)

# defining the x
x = np.arange(1,5,0.1)

#Accessing each of the subplots through its index
ax[0][0].plot(x,x**3)
ax[0][0].set_title('cube')

ax[0][1].plot(x,np.sqrt(x))
ax[0][1].set_title('square root')

# e ^ x, e = 2.718

ax[1][0].plot(x,np.exp(x))
ax[1][0].set_title('exp')



ax[1][1].plot(x,np.log10(x))
ax[1][1].set_title('log')


plt.show()

# %%
# Another way to use subplots


# Compute the x and y coordinates for points on sine and cosine curves
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)
y_tan = np.tan(x)
y_sqrt = np.sqrt(x)


# Set up a subplot grid that has height 2 and width 1,
# and set the first such subplot as active.

plt.subplot(2, 2, 1)
# Make the first plot
plt.plot(x, y_sin)
plt.title('Sine')

# Set the second subplot as active, and make the second plot.
plt.subplot(2, 2, 2)
plt.plot(x, y_cos)
plt.title('Cosine')

plt.subplot(2, 2, 3)
plt.plot(x, y_tan)
plt.title('Tangent')

plt.subplot(2, 2, 4)
plt.plot(x, y_sqrt)
plt.title('Square Root')


# Show the figure.
plt.show()

# %% [markdown]
# # Animation function in MatPlotLib
#
# Matplotlib can also be used for animating plots.
#
# As such, animations could not been embedded inline into jupyter notebooks. But in the case of .py files, once the animation function is defined, calling ```plt.show``` will work.
#
# However Matplotlib 1.5.1 onwards supports inline display of animations in the notebook with the ```to_html5_video method```, which converts the animation to an h264 encoded video (the same thing used to encode mp4 videos) and embeddeds it directly in the notebook.

# %%
from matplotlib import animation, rc
from IPython.display import HTML

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

# setting the x and y lim not necessary
ax.set_xlim(( 0, 2))
ax.set_ylim((-2, 2))

# initialising the plot element by plotting an empty list
[line] = ax.plot([], [],"ro", lw=2)


plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
# animation function. This is called sequentially

# the animation function keeps changing the value of i everytime its called. This is used to update the value of y
# hence changing the plot over time. 
# Once the data is changed the new data is set on the line element initialised above and then returned.
def animate(i):
    x = np.linspace(0, 2, 50)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return [line]

# %%
# this is the animation function where we choose the figure, the animation function defined above, 
# the number of frames and the time delay between the two frames (in millis).
anim = animation.FuncAnimation(fig, animate, frames=100, interval=20)

# 1 second = 1000ms / 20 milliseconds
#print(1000/20)

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## Animating Scatter Plots
#
# Suppose you have a scatter plot, `scat = ax.scatter(...)`, then you can
#
# `scat.set_offsets(array)` - change positions
#
# `scat.set_sizes(array)` - set sizes
#
# `scat.set_array(array)` - change color

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

# setting the x and y lim not necessary
ax.set_xlim(( 0, 2))
ax.set_ylim((-2, 2))

# initialising the plot element by plotting an empty list
scat = ax.scatter([], [])

# %%
# animation function. This is called sequentially

# the animation function keeps changing the value of i everytime its called. This is used to update the value of y
# hence changing the plot over time. 
# Once the data is changed the new data is set on the scatter element initialised above and then returned.
def animateOffsets(i):
    x = np.linspace(0, 2, 10)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    data = [x,y]
    data = np.asarray(data).T # .T = .transpose()
    scat.set_offsets(data)
    return [scat]

# %%
anim1 = animation.FuncAnimation(fig, animateOffsets, frames=100, interval=20)

# we are supplying a function which contains the information on what the each frame should look like

# %% [markdown]
# Now converting it into a video:

# %%
HTML(anim1.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
#resetting the scat:

fig, ax = plt.subplots()

ax.set_xlim(( 0, 2))
ax.set_ylim((-2, 2))

scat = ax.scatter([], [])

# now let's change the sizes as well:
def animateSizes(i):
    x = np.linspace(0,2,10)
    y = np.sin(2 * np.pi * (x- 0.01 * i))
    sizes = np.sin(2 * np.pi * (x - 2*0.01 * i))
    
    data = [x,y]
    data = np.asarray(data).T
    scat.set_offsets(data)
    
    scat.set_sizes(300*(sizes)**2+100)
    return [scat]

anim2 = animation.FuncAnimation(fig, animateSizes, frames=200, interval=10)
HTML(anim2.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
#resetting the scat:

fig, ax = plt.subplots()

ax.set_xlim(( 0, 2))
ax.set_ylim((-2, 2))
#setting the color map to show vibrant rainbow colors:
plt.set_cmap("hsv")

scat = ax.scatter([], [])

# now let's change all the three (color, shape and position)!
def animateSizes(i):
    x = np.linspace(0,2,40)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    #sizes = np.sin(2 * np.pi * (x - 2*0.01 * i))
    colors = abs(np.cos(2*np.pi*(3*x - 0.01*i)))
    data = [x,y]
    data = np.asarray(data).T
    scat.set_offsets(data)
    #scat.set_sizes(300*abs(sizes)**2+100)
    scat.set_array(colors)
    return [scat]

anim2 = animation.FuncAnimation(fig, animateSizes, frames=100, interval=20)
HTML(anim2.to_html5_video())

# kaggle
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# The [`set_cmap`](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.set_cmap.html#matplotlib.pyplot.set_cmap)  function
#
# More infomation on [color maps](https://matplotlib.org/tutorials/colors/colormaps.html)

# %% [markdown]
# # Saving Plots and Animations to your computer for later use:
# (and increasing the resolution if you need)

# %%
x = np.random.uniform(0,1,[10,10,3])
plt.figure(figsize=[10,10])
plt.imshow(x)
plt.savefig("randompixels2.png")
plt.imsave("randompixels.png",x)

# %% [markdown]
# However, `imsave` only works for matrices (which are interpreted internally as normal RGB images). Plots, on the other hand, need to be saved differently (in fact, even images can be saved the way plots are, but plots can't be saved in the same way as images).

# %%
#Increasing the entire plot size:
plt.figure(figsize=(14,6)) # the numbers are in INCHES, beware :)

plt.subplot(2,2,1)
plt.plot(y_sin,color="orange")
plt.title("sine")
plt.subplot(2,2,2)
plt.plot(y_cos,color="darkcyan")
plt.title("cosine")
plt.subplot(2,2,3)
plt.plot(y_tan,color="indianred")
plt.title("tangent")
plt.subplot(2,2,4)
plt.plot(y_sqrt,color="hotpink")
plt.title("square root")

#Here, we are adjusting the spacing:
plt.subplots_adjust(hspace=0.7,wspace=0.2) #hspace = height spacing, wspace = width spacing
plt.savefig("4plots.png")
plt.show()

# %% [markdown]
# Now, if we want to save the last plot made by our plotter, we need to use the function: `savefig`
